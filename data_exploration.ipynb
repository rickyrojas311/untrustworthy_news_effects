# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df = pd.read_csv("master_data_2020.csv")
df.columns.tolist()
# Out:
# ['consent',
#  'encountered_fakenews1',
#  'fakenews_pctg1',
#  'fnews_story1',
#  'fnews_story2',
#  'fnews_story3',
#  'fnews_story4',
#  'fnews_story5',
#  'fnews_story6',
#  'fnews_story7',
#  'fnews_story8',
#  'fnews_story9',
#  'fnews_story0',
#  'certainty_nofakenews1',
#  'respondent_stories_1',
#  'respondent_stories_2',
#  'respondent_stories_3',
#  'respondent_stories_4',
#  'respondent_stories_5',
#  'respondent_stories_6',
#  'respondent_stories_7',
#  'respondent_stories_8',
#  'respondent_stories_9',
#  'respondent_stories_10',
#  'fnews_story1_source',
#  'fnews_story1_recognize',
#  'fnews_story2_source',
#  'fnews_story2_recognize',
#  'fnews_story3_source',
#  'fnews_story3_recognize',
#  'fnews_story4_source',
#  'fnews_story4_recognize',
#  'fnews_story5_source',
#  'fnews_story5_recognize',
#  'fnews_story6_source',
#  'fnews_story6_recognize',
#  'fnews_story7_source',
#  'fnews_story7_recognize',
#  'fnews_story8_source',
#  'fnews_story8_recognize',
# ...

# %% [markdown]
# ['consent',
#  'encountered_fakenews1',
#  'fakenews_pctg1',
#  'fnews_story1',
#  'fnews_story2',
#  'fnews_story3',
#  'fnews_story4',
#  'fnews_story5',
#  'fnews_story6',
#  'fnews_story7',
#  'fnews_story8',
#  'fnews_story9',
#  'fnews_story0',
#  'certainty_nofakenews1',
#  'respondent_stories_1',
#  'respondent_stories_2',
#  'respondent_stories_3',
#  'respondent_stories_4',
#  'respondent_stories_5',
#  'respondent_stories_6',
#  'respondent_stories_7',
#  'respondent_stories_8',
#  'respondent_stories_9',
#  'respondent_stories_10',
#  'fnews_story1_source',
#  'fnews_story1_recognize',
#  'fnews_story2_source',
#  'fnews_story2_recognize',
#  'fnews_story3_source',
#  'fnews_story3_recognize',
#  'fnews_story4_source',
#  'fnews_story4_recognize',
#  'fnews_story5_source',
#  'fnews_story5_recognize',
#  'fnews_story6_source',
#  'fnews_story6_recognize',
#  'fnews_story7_source',
#  'fnews_story7_recognize',
#  'fnews_story8_source',
#  'fnews_story8_recognize',
#  'fnews_story9_source',
#  'fnews_story9_recognize',
#  'fnews_story0_source',
#  'fnews_story0_recognize',
#  'biggest_source1',
#  'biggest_source_other1',
#  'detecting_fakenews1',
#  'fakenews_trend1',
#  'socmed_use',
#  'tf_adv',
#  'tf_pdf',
#  'tf_spy',
#  'tf_wiki',
#  'tf_cache',
#  'tf_phishing',
#  'tie_senate',
#  'filibuster',
#  'presidential_terms',
#  'electoral_college',
#  'presvote2020',
#  'gender4',
#  'gender4_other',
#  'birthyr',
#  'age',
#  'age4',
#  'race',
#  'race_other',
#  'hispanic',
#  'hispanic_origin_1',
#  'hispanic_origin_2',
#  'hispanic_origin_3',
#  'hispanic_origin_4',
#  'race4',
#  'educ',
#  'educ4',
#  'inputstate',
#  'region',
#  'newsint',
#  'sourcenews_new',
#  'votereg',
#  'turnout16',
#  'presvote16post',
#  'presvote16post_t',
#  'pid3',
#  'pid3_other',
#  'pid7',
#  'ideo5',
#  'intuse',
#  'conf02',
#  'conf05',
#  'conf07',
#  'conf08',
#  'conf10',
#  'conf11',
#  'conf12',
#  'starttime',
#  'endtime',
#  'weight',
#  'caseid',
#  'encountered_fakenews1_post',
#  'fakenews_pctg1_post',
#  'fnews_story1_post',
#  'fnews_story2_post',
#  'fnews_story3_post',
#  'fnews_story4_post',
#  'fnews_story5_post',
#  'fnews_story6_post',
#  'fnews_story7_post',
#  'fnews_story8_post',
#  'fnews_story9_post',
#  'fnews_story0_post',
#  'certainty_nofakenews1_post',
#  'respondent_stories_1_post',
#  'respondent_stories_2_post',
#  'respondent_stories_3_post',
#  'respondent_stories_4_post',
#  'respondent_stories_5_post',
#  'respondent_stories_6_post',
#  'respondent_stories_7_post',
#  'respondent_stories_8_post',
#  'respondent_stories_9_post',
#  'respondent_stories_10_post',
#  'fnews_story1_source_post',
#  'fnews_story1_recognize_post',
#  'fnews_story2_source_post',
#  'fnews_story2_recognize_post',
#  'fnews_story3_source_post',
#  'fnews_story3_recognize_post',
#  'fnews_story4_source_post',
#  'fnews_story4_recognize_post',
#  'fnews_story5_source_post',
#  'fnews_story5_recognize_post',
#  'fnews_story6_source_post',
#  'fnews_story6_recognize_post',
#  'fnews_story7_source_post',
#  'fnews_story7_recognize_post',
#  'fnews_story8_source_post',
#  'fnews_story8_recognize_post',
#  'fnews_story9_source_post',
#  'fnews_story9_recognize_post',
#  'fnews_story0_source_post',
#  'fnews_story0_recognize_post',
#  'biggest_source1_post',
#  'biggest_source_other1_post',
#  'detecting_fakenews1_post',
#  'fakenews_trend1_post',
#  'socmed_use_post',
#  'zipcode',
#  'occupation',
#  'presvote20post',
#  'presvote20post_t',
#  'election_behaviors_1',
#  'election_behaviors_2',
#  'election_behaviors_3',
#  'election_behaviors_4',
#  'election_behaviors_5',
#  'election_behaviors_6',
#  'election_behaviors_7',
#  'election_behaviors_8',
#  'election_behaviors_9',
#  'election_behaviors_10',
#  'election_behaviors_11',
#  'election_behaviors_12',
#  'election_behaviors_13',
#  'election_behaviors_14',
#  'election_behaviors_15',
#  'election_behaviors_16',
#  'election_behaviors_17',
#  'election_behaviors_oth',
#  'won_election',
#  'covid_positive',
#  'covid_month',
#  'covid_date',
#  'self_isolation',
#  'starttime_post',
#  'endtime_post',
#  'weight_post',
#  'presvote20combined',
#  'race4_black',
#  'race4_hispanic',
#  'race4_other',
#  'race4_white',
#  'gender4_female',
#  'gender4_male',
#  'gender4_other_2',
#  'gender4_prefer_not_to_say',
#  'ideo5_conservative',
#  'ideo5_liberal',
#  'ideo5_moderate',
#  'ideo5_not_sure',
#  'ideo5_very_conservative',
#  'ideo5_very_liberal',
#  'age4_30_44',
#  'age4_45_64',
#  'age4_65',
#  'age4_under_30',
#  'educ_factor',
#  'education',
#  'college',
#  'trump_support',
#  'female',
#  'non_white',
#  'knowledge',
#  'interest',
#  'untrustworthy_n',
#  'total_n',
#  'untrustworthy_flag',
#  'percentage_of_total',
#  'untrustworthy_ng_n',
#  'untrustworthy_ng_flag',
#  'percentage_of_total_ng',
#  'grinberg_n',
#  'grinberg_flag',
#  'grinberg_percentage_of_total',
#  'untrustworthy_conservative_n',
#  'untrustworthy_liberal_n',
#  'untrustworthy_conservative_flag',
#  'untrustworthy_liberal_flag',
#  'hard_news_n',
#  'hard_news_flag',
#  'hard_news_bin',
#  'hard_news_conservative_n',
#  'hard_news_liberal_n',
#  'hard_news_conservative_flag',
#  'hard_news_liberal_flag',
#  'fact_check_n',
#  'fact_check_flag',
#  'mean_ideology',
#  'ideology_bin',
#  'hard_news_bin_all',
#  'total_n_bin_all',
#  'untrustworthy_conservative_percentage_info_diet',
#  'untrustworthy_liberal_percentage_info_diet',
#  'untrustworthy_all_percentage_info_diet',
#  'biden_support']

# %%
df = pd.read_csv("master_data_2020.csv")
df = df[~df["presvote20post"].isna()]

# ==========================================
# 1. DEFINE SOURCE COLUMNS
# ==========================================
treatment = "untrustworthy_flag"
raw_vote_choice_col = "presvote20post"

# ==========================================
# 2. OVERWRITE & CLEAN TARGET OUTCOMES FROM TEXT
# ==========================================
# Ensure we capture text responses and handle any trailing whitespaces cleanly
vote_series = df[raw_vote_choice_col].astype(str).str.strip()

# 1. Fix Biden Vote (1 if explicitly voted for Biden, 0 otherwise)
df["voted_biden_2020"] = np.where(vote_series == "Joe Biden", 1, 0)

# 2. Fix Trump Vote (1 if explicitly voted for Trump, 0 otherwise)
df["voted_trump_2020"] = np.where(vote_series == "Donald Trump", 1, 0)

# 3. Create Turnout (0 if they didn't vote or skipped, 1 if they cast a ballot)
# Based on your data, non-voters show up as "Did not vote for President" or missing strings
df["turnout_2020_binary"] = np.where(
    vote_series.str.contains("did not vote|skipped|__na__", case=False, na=True),
    0,
    1
)

# Structure our clean target dictionary for the loop
outcomes = {
    "2020 Turnout": "turnout_2020_binary",
    "Voted for Biden": "voted_biden_2020",
    "Voted for Trump": "voted_trump_2020",
}

# ==========================================
# 3. COMPREHENSIVE FEATURE ENGINEERING (CONDENSED & STREAMLINED)
# ==========================================
# Process Digital Literacy Index
tf_cols = ["tf_adv", "tf_pdf", "tf_spy", "tf_wiki", "tf_cache", "tf_phishing"]
df_tf = df[tf_cols].map(
    lambda val: int(str(val).strip().split()[0])
    if pd.notna(val) and str(val).strip().split()[0].isdigit()
    else np.nan
)
df["digital_literacy_index"] = df_tf.mean(axis=1)

# Linearized Political Mappings
df["ideo5_linear"] = df["ideo5"].map({"Very liberal": 1, "Liberal": 2, "Moderate": 3, "Conservative": 4, "Very conservative": 5})
df["pid7_linear"] = df["pid7"].map({"Strong Democrat": 1, "Not very strong Democrat": 2, "Lean Democrat": 3, "Independent": 4, "Lean Republican": 5, "Not very strong Republican": 6, "Strong Republican": 7})

# Linearized Social Media Scale
socmed_mapping = {
    "Less than 10 minutes per day": 1, "10–30 minutes per day": 2, "31–60 minutes per day": 3,
    "1–2 hours per day": 4, "2–3 hours per day": 5, "More than 3 hours per day": 6
}
df["socmed_use_linear"] = df["socmed_use"].astype(str).str.strip().map(socmed_mapping)

# --- NEW: Condense News Interest into a Linear Scale ---
newsint_mapping = {
    "Hardly at all": 1,
    "Only now and then": 2,
    "Some of the time": 3,
    "Most of the time": 4
}
df["newsint_linear"] = df["newsint"].astype(str).str.strip().map(newsint_mapping)

# --- NEW: Condense Internet Use Frequency into a Linear Scale ---
intuse_mapping = {
    "Less often": 1,
    "About once a day": 3,
    "Several times a day": 4,
    "A few times a week": 2  # Catching common top-tier survey labels if present
}
# Fallback to handle "Several times a day" as the top option if "Almost constantly" isn't used
df["intuse_linear"] = df["intuse"].astype(str).str.strip().map(intuse_mapping).fillna(3)

# --- NEW: Condense 2016 Vote into Trump, Clinton, and Other ---
# Modified 2016 vote processing function
def condense_2016_vote_fixed(val):
    val_str = str(val).strip()
    if val_str in ["Hillary Clinton", "Donald Trump"]:
        return val_str
    # Explicitly group non-voters and missing responses into a valid category string
    elif pd.isna(val) or val_str in ["__NA__", "nan", "Did not vote", "Did not vote for President"]:
        return "Did Not Vote"
    else:
        return "Other"

df["presvote16post_condensed"] = df["presvote16post"].apply(condense_2016_vote_fixed)

# REMOVE 'turnout16' from your categorical_covariates list!
# 'presvote16post_condensed' now handles turnout implicitly.
categorical_covariates = [
    "race4", 
    "educ4", 
    "region", 
    "presvote16post_condensed" # Will generate dummies for Clinton, Other, and Did Not Vote. 
]
# Gather all our dense numeric/linear features
linear_features = [
    "ideo5_linear", 
    "pid7_linear", 
    "socmed_use_linear", 
    "newsint_linear", 
    "intuse_linear"
]

# ==========================================
# 4. DESIGN MATRIX GENERATION (THE COVARIATES)
# ==========================================
core_cols = [treatment] + list(outcomes.values()) + ["age", "female"]
engineered_continuous = ["digital_literacy_index"]


# Clean complete-case alignment
all_processed_cols = core_cols + engineered_continuous + linear_features + categorical_covariates
df_clean = df[all_processed_cols].dropna().copy()

# Build the final compact X Matrix
# 1. Generate all dummies with drop_first=False so we can manually control the baselines
X_matrix = pd.get_dummies(
    df_clean[["age", "female"] + engineered_continuous + linear_features + categorical_covariates],
    columns=categorical_covariates,
    drop_first=False,
    dtype=int,
)

# 2. Define exactly one baseline reference column to drop from each categorical group
baselines_to_drop = [
    'presvote16post_condensed_Donald Trump',  # 2016 Vote baseline
    'race4_White',                            # Race baseline
    'educ4_College grad',                     # Education baseline
    'region_Midwest',                         # Region baseline
]

# 3. Drop them safely from the matrix
X_matrix = X_matrix.drop(columns=baselines_to_drop, errors='ignore')

# ==========================================
# 5. FINAL AIPW INPUT EXTRACTION
# ==========================================
W = df_clean[treatment].astype(int).values
Y_turnout = df_clean[outcomes["2020 Turnout"]].astype(int).values
Y_biden = df_clean[outcomes["Voted for Biden"]].astype(int).values
Y_trump = df_clean[outcomes["Voted for Trump"]].astype(int).values

print("--- PIPELINE VERIFICATION ---")
print(f"Total valid sample size (N): {len(df_clean)}")
print(f"Total covariates in X_matrix: {X_matrix.shape[1]}")
print(f"Mean 2020 Turnout rate: {Y_turnout.mean():.2%}")
print(f"Mean unconditional Biden support: {Y_biden.mean():.2%}")
print(f"Mean unconditional Trump support: {Y_trump.mean():.2%}")
# Out:
# --- PIPELINE VERIFICATION ---
# Total valid sample size (N): 956
# Total covariates in X_matrix: 20
# Mean 2020 Turnout rate: 97.38%
# Mean unconditional Biden support: 59.73%
# Mean unconditional Trump support: 35.46%

# %%
# ==========================================
# OVERLAP ASSUMPTION CHECK (for AIPW)
# ==========================================
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# --- 1. Fit propensity score model ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_matrix.values)

ps_model = LogisticRegression(max_iter=1000, C=1.0, random_state=42)
ps_model.fit(X_scaled, W)
ps = ps_model.predict_proba(X_scaled)[:, 1]

# --- 2. Plot propensity score distributions by treatment group ---
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Histogram
axes[0].hist(ps[W == 0], bins=30, alpha=0.6, density=True, label="Control (not exposed)", color="steelblue")
axes[0].hist(ps[W == 1], bins=30, alpha=0.6, density=True, label="Treated (exposed)",     color="tomato")
axes[0].axvline(0.1, color="black", linestyle="--", linewidth=0.8, label="Trim bounds (0.1 / 0.9)")
axes[0].axvline(0.9, color="black", linestyle="--", linewidth=0.8)
axes[0].set_xlabel("Propensity Score  P(W=1 | X)")
axes[0].set_ylabel("Density")
axes[0].set_title("Overlap: Propensity Score Distributions")
axes[0].legend()

# Log-odds plot (better for spotting extremes)
log_odds = np.log(ps / (1 - ps + 1e-9))
axes[1].hist(log_odds[W == 0], bins=30, alpha=0.6, density=True, label="Control", color="steelblue")
axes[1].hist(log_odds[W == 1], bins=30, alpha=0.6, density=True, label="Treated", color="tomato")
axes[1].set_xlabel("Log-Odds of Propensity Score")
axes[1].set_ylabel("Density")
axes[1].set_title("Overlap: Log-Odds Scale")
axes[1].legend()

plt.tight_layout()
plt.show()

# --- 3. Summary statistics ---
TRIM_LO, TRIM_HI = 0.05, 0.95

n_extreme  = ((ps < TRIM_LO) | (ps > TRIM_HI)).sum()
n_extreme2 = ((ps < 0.10)    | (ps > 0.90)).sum()

print("=== Propensity Score Summary ===")
print(f"  Overall range : [{ps.min():.4f}, {ps.max():.4f}]")
print(f"  Treated  (n={W.sum()})  range: [{ps[W==1].min():.4f}, {ps[W==1].max():.4f}]  mean={ps[W==1].mean():.3f}")
print(f"  Control  (n={(W==0).sum()})  range: [{ps[W==0].min():.4f}, {ps[W==0].max():.4f}]  mean={ps[W==0].mean():.3f}")
print()
print(f"  Outside [0.05, 0.95]: {n_extreme} obs  ({n_extreme/len(W):.1%})")
print(f"  Outside [0.10, 0.90]: {n_extreme2} obs  ({n_extreme2/len(W):.1%})")

# --- 4. Effective sample size (ESS) — sensitive to extreme weights ---
ipw_treated = W / ps
ipw_control = (1 - W) / (1 - ps)
ess_treated = ipw_treated[W==1].sum()**2 / (ipw_treated[W==1]**2).sum()
ess_control = ipw_control[W==0].sum()**2 / (ipw_control[W==0]**2).sum()

print()
print("=== IPW Effective Sample Size ===")
print(f"  Treated  actual n={W.sum()},  ESS={ess_treated:.1f}  ({ess_treated/W.sum():.1%} of treated)")
print(f"  Control  actual n={(W==0).sum()},  ESS={ess_control:.1f}  ({ess_control/(W==0).sum():.1%} of control)")
print()
print("Interpretation:")
print("  ESS/n < 50% → extreme weights dominating; consider trimming.")
print("  Overlapping histogram peaks → overlap assumption plausible.")
print("  Separation in log-odds plot → overlap violation for those subgroups.")
# Out:
# === Propensity Score Summary ===
#   Overall range : [0.0286, 0.7736]
#   Treated  (n=311)  range: [0.0299, 0.7300]  mean=0.392
#   Control  (n=645)  range: [0.0286, 0.7736]  mean=0.293
#
#   Outside [0.05, 0.95]: 15 obs  (1.6%)
#   Outside [0.10, 0.90]: 58 obs  (6.1%)
#
# === IPW Effective Sample Size ===
#   Treated  actual n=311,  ESS=201.8  (64.9% of treated)
#   Control  actual n=645,  ESS=608.6  (94.4% of control)
#
# Interpretation:
#   ESS/n < 50% → extreme weights dominating; consider trimming.
#   Overlapping histogram peaks → overlap assumption plausible.
#   Separation in log-odds plot → overlap violation for those subgroups.

# %%
# ==========================================
# SAVE CLEANED PIPELINE DATA
# ==========================================
# pipeline_clean.csv   — df_clean: one row per respondent, pre-dummy features
# pipeline_X_matrix.csv — design matrix (dummies expanded, baselines dropped)
#                         with treatment + outcome columns prepended

df_clean.to_csv("pipeline_clean.csv", index=False)

X_matrix_out = X_matrix.copy()
X_matrix_out.insert(0, "untrustworthy_flag",  df_clean[treatment].values)
X_matrix_out.insert(1, "turnout_2020_binary", df_clean["turnout_2020_binary"].values)
X_matrix_out.insert(2, "voted_biden_2020",    df_clean["voted_biden_2020"].values)
X_matrix_out.insert(3, "voted_trump_2020",    df_clean["voted_trump_2020"].values)
X_matrix_out.to_csv("pipeline_X_matrix.csv", index=False)

print(f"pipeline_clean.csv     → {df_clean.shape[0]:,} rows × {df_clean.shape[1]} cols  (pre-dummy features)")
print(f"pipeline_X_matrix.csv  → {X_matrix_out.shape[0]:,} rows × {X_matrix_out.shape[1]} cols  (design matrix + outcomes)")
print()
print("Columns in pipeline_clean.csv:")
for col in df_clean.columns:
    print(f"  {col}")
# Out:
# pipeline_clean.csv     → 956 rows × 16 cols  (pre-dummy features)
# pipeline_X_matrix.csv  → 956 rows × 24 cols  (design matrix + outcomes)
#
# Columns in pipeline_clean.csv:
#   untrustworthy_flag
#   turnout_2020_binary
#   voted_biden_2020
#   voted_trump_2020
#   age
#   female
#   digital_literacy_index
#   ideo5_linear
#   pid7_linear
#   socmed_use_linear
#   newsint_linear
#   intuse_linear
#   race4
#   educ4
#   region
#   presvote16post_condensed
