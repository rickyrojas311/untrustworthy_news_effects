# %%
import pandas as pd

# %%
df = pd.read_csv("master_data_2020.csv")
df.columns
# Out:
# Index(['consent', 'encountered_fakenews1', 'fakenews_pctg1', 'fnews_story1',
#        'fnews_story2', 'fnews_story3', 'fnews_story4', 'fnews_story5',
#        'fnews_story6', 'fnews_story7',
#        ...
#        'fact_check_n', 'fact_check_flag', 'mean_ideology', 'ideology_bin',
#        'hard_news_bin_all', 'total_n_bin_all',
#        'untrustworthy_conservative_percentage_info_diet',
#        'untrustworthy_liberal_percentage_info_diet',
#        'untrustworthy_all_percentage_info_diet', 'biden_support'],
#       dtype='object', length=235)

# %%
df["mean_ideology"]
# Out:
# 0      -0.121400
# 1      -0.411549
# 2      -0.082848
# 3      -0.084000
# 4      -0.041849
#           ...
# 1146         NaN
# 1147   -0.494486
# 1148   -0.188400
# 1149   -0.369471
# 1150   -0.233167
# Name: mean_ideology, Length: 1151, dtype: float64
